# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.50-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.5.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\eduar\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from sqlalchemy) (4.15.0)
# Downloading sqlalchemy-2.0.50-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------- ----- 1.8/2.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.5 MB/s  0:00:00
# Downloading greenlet-3.5.1-cp311-cp311-win_amd64.whl (238 kB)
# Installing collected packages: greenlet, sqlalchemy
#
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    ---------------------------------------- 0/2 [greenlet]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    -------------------- ------------------- 1/2 [sqlalchemy]
#    ---------------------------------------- 2/2 [sqlalchemy]
#
# Successfully installed greenlet-3.5.1 sqlalchemy-2.0.50
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install psycopg2-binary
# Out:
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.12-cp311-cp311-win_amd64.whl.metadata (5.1 kB)
# Downloading psycopg2_binary-2.9.12-cp311-cp311-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    -------------------------- ------------- 1.8/2.8 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 10.0 MB/s  0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.12

# %%
from sqlalchemy import create_engine

engine = create_engine(
    'postgresql://postgres:edu123@localhost/dw_ventas'
)

print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
import pandas as pd

df = pd.read_csv("ventas.csv")

df.head()
# Out:
#         fecha    nombre    ciudad   producto    categoria  cantidad  total
# 0  2025-01-12    Carlos   Orizaba    Celular  Electronica         3  18000
# 1  2025-02-08   Daniela   Cordoba     Laptop  Electronica         2  24000
# 2  2025-03-15  Fernando    Xalapa     Tablet  Electronica         4  12000
# 3  2025-04-10  Gabriela  Veracruz  Impresora      Oficina         2   5000
# 4  2025-05-18    Hector    Puebla    Monitor  Electronica         3   9000

# %%
dim_cliente = df[['nombre','ciudad']].drop_duplicates()

dim_cliente
# Out:
#      nombre    ciudad
# 0    Carlos   Orizaba
# 1   Daniela   Cordoba
# 2  Fernando    Xalapa
# 3  Gabriela  Veracruz
# 4    Hector    Puebla
# 5    Isabel   Orizaba
# 6     Jorge   Cordoba
# 7     Karla    Xalapa
# 8  Leonardo  Veracruz
# 9    Monica    Puebla

# %%
dim_producto = df[['producto','categoria']].drop_duplicates()

dim_producto
# Out:
#       producto       categoria
# 0      Celular     Electronica
# 1       Laptop     Electronica
# 2       Tablet     Electronica
# 3    Impresora         Oficina
# 4      Monitor     Electronica
# 5      Teclado      Accesorios
# 6        Mouse      Accesorios
# 7       Webcam      Accesorios
# 8   Disco Duro  Almacenamiento
# 9  Memoria USB  Almacenamiento

# %%
dim_fecha = df[['fecha']].drop_duplicates()

dim_fecha['fecha'] = pd.to_datetime(dim_fecha['fecha'])

dim_fecha['mes'] = dim_fecha['fecha'].dt.month
dim_fecha['anio'] = dim_fecha['fecha'].dt.year

dim_fecha
# Out:
#        fecha  mes  anio
# 0 2025-01-12    1  2025
# 1 2025-02-08    2  2025
# 2 2025-03-15    3  2025
# 3 2025-04-10    4  2025
# 4 2025-05-18    5  2025
# 5 2025-06-05    6  2025
# 6 2025-06-09    6  2025
# 7 2025-06-11    6  2025
# 8 2025-06-15    6  2025
# 9 2025-06-20    6  2025

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)

dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)

dim_fecha.to_sql(
    'dim_fecha',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#     id_cliente    nombre    ciudad
# 0            1    Carlos   Orizaba
# 1            2   Daniela   Cordoba
# 2            3  Fernando    Xalapa
# 3            4  Gabriela  Veracruz
# 4            5    Hector    Puebla
# 5            6    Isabel   Orizaba
# 6            7     Jorge   Cordoba
# 7            8     Karla    Xalapa
# 8            9  Leonardo  Veracruz
# 9           10    Monica    Puebla
# 10          11    Carlos   Orizaba
# 11          12   Daniela   Cordoba
# 12          13  Fernando    Xalapa
# 13          14  Gabriela  Veracruz
# 14          15    Hector    Puebla
# 15          16    Isabel   Orizaba
# 16          17     Jorge   Cordoba
# 17          18     Karla    Xalapa
# 18          19  Leonardo  Veracruz
# 19          20    Monica    Puebla
# 20          21    Carlos   Orizaba
# 21          22   Daniela   Cordoba
# 22          23  Fernando    Xalapa
# 23          24  Gabriela  Veracruz
# 24          25    Hector    Puebla
# 25          26    Isabel   Orizaba
# 26          27     Jorge   Cordoba
# 27          28     Karla    Xalapa
# 28          29  Leonardo  Veracruz
# 29          30    Monica    Puebla

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

productos_db
# Out:
#     id_producto     producto       categoria
# 0             1      Celular     Electronica
# 1             2       Laptop     Electronica
# 2             3       Tablet     Electronica
# 3             4    Impresora         Oficina
# 4             5      Monitor     Electronica
# 5             6      Teclado      Accesorios
# 6             7        Mouse      Accesorios
# 7             8       Webcam      Accesorios
# 8             9   Disco Duro  Almacenamiento
# 9            10  Memoria USB  Almacenamiento
# 10           11      Celular     Electronica
# 11           12       Laptop     Electronica
# 12           13       Tablet     Electronica
# 13           14    Impresora         Oficina
# 14           15      Monitor     Electronica
# 15           16      Teclado      Accesorios
# 16           17        Mouse      Accesorios
# 17           18       Webcam      Accesorios
# 18           19   Disco Duro  Almacenamiento
# 19           20  Memoria USB  Almacenamiento
# 20           21      Celular     Electronica
# 21           22       Laptop     Electronica
# 22           23       Tablet     Electronica
# 23           24    Impresora         Oficina
# 24           25      Monitor     Electronica
# 25           26      Teclado      Accesorios
# 26           27        Mouse      Accesorios
# 27           28       Webcam      Accesorios
# 28           29   Disco Duro  Almacenamiento
# 29           30  Memoria USB  Almacenamiento

# %%
tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

tiempo_db
# Out:
#     id_fecha       fecha  mes  anio
# 0          1  2025-01-12    1  2025
# 1          2  2025-02-08    2  2025
# 2          3  2025-03-15    3  2025
# 3          4  2025-04-10    4  2025
# 4          5  2025-05-18    5  2025
# 5          6  2025-06-05    6  2025
# 6          7  2025-06-09    6  2025
# 7          8  2025-06-11    6  2025
# 8          9  2025-06-15    6  2025
# 9         10  2025-06-20    6  2025
# 10        11  2025-01-12    1  2025
# 11        12  2025-02-08    2  2025
# 12        13  2025-03-15    3  2025
# 13        14  2025-04-10    4  2025
# 14        15  2025-05-18    5  2025
# 15        16  2025-06-05    6  2025
# 16        17  2025-06-09    6  2025
# 17        18  2025-06-11    6  2025
# 18        19  2025-06-15    6  2025
# 19        20  2025-06-20    6  2025

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
# Empty DataFrame
# Columns: [id_cliente, nombre, ciudad]
# Index: []

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#    id_cliente    nombre    ciudad
# 0           1    Carlos   Orizaba
# 1           2   Daniela   Cordoba
# 2           3  Fernando    Xalapa
# 3           4  Gabriela  Veracruz
# 4           5    Hector    Puebla
# 5           6    Isabel   Orizaba
# 6           7     Jorge   Cordoba
# 7           8     Karla    Xalapa
# 8           9  Leonardo  Veracruz
# 9          10    Monica    Puebla

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#    id_cliente    nombre    ciudad
# 0           1    Carlos   Orizaba
# 1           2   Daniela   Cordoba
# 2           3  Fernando    Xalapa
# 3           4  Gabriela  Veracruz
# 4           5    Hector    Puebla
# 5           6    Isabel   Orizaba
# 6           7     Jorge   Cordoba
# 7           8     Karla    Xalapa
# 8           9  Leonardo  Veracruz
# 9          10    Monica    Puebla

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

productos_db
# Out:
#    id_producto     producto       categoria
# 0            1      Celular     Electronica
# 1            2       Laptop     Electronica
# 2            3       Tablet     Electronica
# 3            4    Impresora         Oficina
# 4            5      Monitor     Electronica
# 5            6      Teclado      Accesorios
# 6            7        Mouse      Accesorios
# 7            8       Webcam      Accesorios
# 8            9   Disco Duro  Almacenamiento
# 9           10  Memoria USB  Almacenamiento

# %%
tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

tiempo_db
# Out:
#    id_fecha       fecha  mes  anio
# 0         1  2025-01-12    1  2025
# 1         2  2025-02-08    2  2025
# 2         3  2025-03-15    3  2025
# 3         4  2025-04-10    4  2025
# 4         5  2025-05-18    5  2025
# 5         6  2025-06-05    6  2025
# 6         7  2025-06-09    6  2025
# 7         8  2025-06-11    6  2025
# 8         9  2025-06-15    6  2025
# 9        10  2025-06-20    6  2025

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#    id_cliente    nombre    ciudad
# 0           1    Carlos   Orizaba
# 1           2   Daniela   Cordoba
# 2           3  Fernando    Xalapa
# 3           4  Gabriela  Veracruz
# 4           5    Hector    Puebla
# 5           6    Isabel   Orizaba
# 6           7     Jorge   Cordoba
# 7           8     Karla    Xalapa
# 8           9  Leonardo  Veracruz
# 9          10    Monica    Puebla

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()
# Out:
#        fecha    nombre    ciudad   producto    categoria  cantidad  total  \
# 0 2025-01-12    Carlos   Orizaba    Celular  Electronica         3  18000
# 1 2025-02-08   Daniela   Cordoba     Laptop  Electronica         2  24000
# 2 2025-03-15  Fernando    Xalapa     Tablet  Electronica         4  12000
# 3 2025-04-10  Gabriela  Veracruz  Impresora      Oficina         2   5000
# 4 2025-05-18    Hector    Puebla    Monitor  Electronica         3   9000
#
#    id_cliente  id_producto  id_fecha  mes  anio
# 0           1            1         1    1  2025
# 1           2            2         2    2  2025
# 2           3            3         3    3  2025
# 3           4            4         4    4  2025
# 4           5            5         5    5  2025

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas
# Out:
#    id_cliente  id_producto  id_fecha  cantidad  total
# 0           1            1         1         3  18000
# 1           2            2         2         2  24000
# 2           3            3         3         4  12000
# 3           4            4         4         2   5000
# 4           5            5         5         3   9000
# 5           6            6         6         6   3600
# 6           7            7         7         8   2400
# 7           8            8         8         2   1800
# 8           9            9         9         5   7500
# 9          10           10        10        10   2000

# %%
fact_ventas.to_sql(
    "fact_ventas",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 10

# %%
productos_db.head()
# Out:
#    id_producto   producto    categoria
# 0            1    Celular  Electronica
# 1            2     Laptop  Electronica
# 2            3     Tablet  Electronica
# 3            4  Impresora      Oficina
# 4            5    Monitor  Electronica

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()
# Out:
#        fecha    nombre    ciudad   producto    categoria  cantidad  total  \
# 0 2025-01-12    Carlos   Orizaba    Celular  Electronica         3  18000
# 1 2025-02-08   Daniela   Cordoba     Laptop  Electronica         2  24000
# 2 2025-03-15  Fernando    Xalapa     Tablet  Electronica         4  12000
# 3 2025-04-10  Gabriela  Veracruz  Impresora      Oficina         2   5000
# 4 2025-05-18    Hector    Puebla    Monitor  Electronica         3   9000
#
#    id_cliente  id_producto  id_fecha  mes  anio
# 0           1            1         1    1  2025
# 1           2            2         2    2  2025
# 2           3            3         3    3  2025
# 3           4            4         4    4  2025
# 4           5            5         5    5  2025

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas
# Out:
#    id_cliente  id_producto  id_fecha  cantidad  total
# 0           1            1         1         3  18000
# 1           2            2         2         2  24000
# 2           3            3         3         4  12000
# 3           4            4         4         2   5000
# 4           5            5         5         3   9000
# 5           6            6         6         6   3600
# 6           7            7         7         8   2400
# 7           8            8         8         2   1800
# 8           9            9         9         5   7500
# 9          10           10        10        10   2000

# %%
pd.read_sql(
    "SELECT * FROM fact_ventas",
    engine
)
# Out:
#    id_venta  id_cliente  id_producto  id_fecha  cantidad    total
# 0         1           1            1         1         3  18000.0
# 1         2           2            2         2         2  24000.0
# 2         3           3            3         3         4  12000.0
# 3         4           4            4         4         2   5000.0
# 4         5           5            5         5         3   9000.0
# 5         6           6            6         6         6   3600.0
# 6         7           7            7         7         8   2400.0
# 7         8           8            8         8         2   1800.0
# 8         9           9            9         9         5   7500.0
# 9        10          10           10        10        10   2000.0

# %%
consulta = """
SELECT
    p.producto,
    SUM(f.total) AS ventas_totales
FROM fact_ventas f
JOIN dim_producto p
    ON f.id_producto = p.id_producto
GROUP BY p.producto
ORDER BY ventas_totales DESC
"""

resultado = pd.read_sql(consulta, engine)

resultado
# Out:
#       producto  ventas_totales
# 0       Laptop         24000.0
# 1      Celular         18000.0
# 2       Tablet         12000.0
# 3      Monitor          9000.0
# 4   Disco Duro          7500.0
# 5    Impresora          5000.0
# 6      Teclado          3600.0
# 7        Mouse          2400.0
# 8  Memoria USB          2000.0
# 9       Webcam          1800.0

# %%
import matplotlib.pyplot as plt

resultado.plot(
    x="producto",
    y="ventas_totales",
    kind="bar"
)

plt.title("Ventas Totales por Producto")
plt.ylabel("Ventas")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.pie(
    resultado["ventas_totales"],
    labels=resultado["producto"],
    autopct="%1.1f%%"
)

plt.title("Porcentaje de Ventas por Producto")

plt.show()
