# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
from sqlalchemy import create_engine

engine = create_engine(
    'postgresql://postgres:edu123@localhost/dw_ventas'
)

print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
import pandas as pd

df = pd.read_csv("../Data/ventas.csv")

df.head()
# Out:
#         fecha    nombre    ciudad   producto    categoria  cantidad  total
# 0  2025-01-12    Carlos   Orizaba    Celular  Electronica         3  18000
# 1  2025-02-08   Daniela   Cordoba     Laptop  Electronica         2  24000
# 2  2025-03-15  Fernando    Xalapa     Tablet  Electronica         4  12000
# 3  2025-04-10  Gabriela  Veracruz  Impresora      Oficina         2   5000
# 4  2025-05-18    Hector    Puebla    Monitor  Electronica         3   9000

# %%
dim_cliente = df[['nombre','ciudad']].drop_duplicates()

dim_cliente
# Out:
#      nombre    ciudad
# 0    Carlos   Orizaba
# 1   Daniela   Cordoba
# 2  Fernando    Xalapa
# 3  Gabriela  Veracruz
# 4    Hector    Puebla
# 5    Isabel   Orizaba
# 6     Jorge   Cordoba
# 7     Karla    Xalapa
# 8  Leonardo  Veracruz
# 9    Monica    Puebla

# %%
dim_producto = df[['producto','categoria']].drop_duplicates()

dim_producto
# Out:
#       producto       categoria
# 0      Celular     Electronica
# 1       Laptop     Electronica
# 2       Tablet     Electronica
# 3    Impresora         Oficina
# 4      Monitor     Electronica
# 5      Teclado      Accesorios
# 6        Mouse      Accesorios
# 7       Webcam      Accesorios
# 8   Disco Duro  Almacenamiento
# 9  Memoria USB  Almacenamiento

# %%
dim_fecha = df[['fecha']].drop_duplicates()

dim_fecha['fecha'] = pd.to_datetime(dim_fecha['fecha'])

dim_fecha['mes'] = dim_fecha['fecha'].dt.month
dim_fecha['anio'] = dim_fecha['fecha'].dt.year

dim_fecha
# Out:
#        fecha  mes  anio
# 0 2025-01-12    1  2025
# 1 2025-02-08    2  2025
# 2 2025-03-15    3  2025
# 3 2025-04-10    4  2025
# 4 2025-05-18    5  2025
# 5 2025-06-05    6  2025
# 6 2025-06-09    6  2025
# 7 2025-06-11    6  2025
# 8 2025-06-15    6  2025
# 9 2025-06-20    6  2025

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)

dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)

dim_fecha.to_sql(
    'dim_fecha',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)
# Out:
# 10

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#     id_cliente    nombre    ciudad
# 0            1    Carlos   Orizaba
# 1            2   Daniela   Cordoba
# 2            3  Fernando    Xalapa
# 3            4  Gabriela  Veracruz
# 4            5    Hector    Puebla
# ..         ...       ...       ...
# 85          86    Isabel   Orizaba
# 86          87     Jorge   Cordoba
# 87          88     Karla    Xalapa
# 88          89  Leonardo  Veracruz
# 89          90    Monica    Puebla
#
# [90 rows x 3 columns]

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

productos_db
# Out:
#     id_producto     producto       categoria
# 0             1      Celular     Electronica
# 1             2       Laptop     Electronica
# 2             3       Tablet     Electronica
# 3             4    Impresora         Oficina
# 4             5      Monitor     Electronica
# ..          ...          ...             ...
# 85           86      Teclado      Accesorios
# 86           87        Mouse      Accesorios
# 87           88       Webcam      Accesorios
# 88           89   Disco Duro  Almacenamiento
# 89           90  Memoria USB  Almacenamiento
#
# [90 rows x 3 columns]

# %%
tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

tiempo_db
# Out:
#     id_fecha       fecha  mes  anio
# 0          1  2025-01-12    1  2025
# 1          2  2025-02-08    2  2025
# 2          3  2025-03-15    3  2025
# 3          4  2025-04-10    4  2025
# 4          5  2025-05-18    5  2025
# 5          6  2025-06-05    6  2025
# 6          7  2025-06-09    6  2025
# 7          8  2025-06-11    6  2025
# 8          9  2025-06-15    6  2025
# 9         10  2025-06-20    6  2025
# 10        11  2025-01-12    1  2025
# 11        12  2025-02-08    2  2025
# 12        13  2025-03-15    3  2025
# 13        14  2025-04-10    4  2025
# 14        15  2025-05-18    5  2025
# 15        16  2025-06-05    6  2025
# 16        17  2025-06-09    6  2025
# 17        18  2025-06-11    6  2025
# 18        19  2025-06-15    6  2025
# 19        20  2025-06-20    6  2025
# 20        21  2025-01-12    1  2025
# 21        22  2025-02-08    2  2025
# 22        23  2025-03-15    3  2025
# 23        24  2025-04-10    4  2025
# 24        25  2025-05-18    5  2025
# 25        26  2025-06-05    6  2025
# 26        27  2025-06-09    6  2025
# 27        28  2025-06-11    6  2025
# 28        29  2025-06-15    6  2025
# 29        30  2025-06-20    6  2025
# 30        31  2025-01-12    1  2025
# 31        32  2025-02-08    2  2025
# 32        33  2025-03-15    3  2025
# 33        34  2025-04-10    4  2025
# 34        35  2025-05-18    5  2025
# 35        36  2025-06-05    6  2025
# 36        37  2025-06-09    6  2025
# 37        38  2025-06-11    6  2025
# 38        39  2025-06-15    6  2025
# 39        40  2025-06-20    6  2025
# 40        41  2025-01-12    1  2025
# 41        42  2025-02-08    2  2025
# 42        43  2025-03-15    3  2025
# 43        44  2025-04-10    4  2025
# 44        45  2025-05-18    5  2025
# 45        46  2025-06-05    6  2025
# 46        47  2025-06-09    6  2025
# 47        48  2025-06-11    6  2025
# 48        49  2025-06-15    6  2025
# 49        50  2025-06-20    6  2025

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db
# Out:
#     id_cliente    nombre    ciudad
# 0            1    Carlos   Orizaba
# 1            2   Daniela   Cordoba
# 2            3  Fernando    Xalapa
# 3            4  Gabriela  Veracruz
# 4            5    Hector    Puebla
# ..         ...       ...       ...
# 85          86    Isabel   Orizaba
# 86          87     Jorge   Cordoba
# 87          88     Karla    Xalapa
# 88          89  Leonardo  Veracruz
# 89          90    Monica    Puebla
#
# [90 rows x 3 columns]

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()
# Out:
#        fecha  nombre   ciudad producto    categoria  cantidad  total  \
# 0 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 1 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 2 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 3 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 4 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
#
#    id_cliente  id_producto  id_fecha  mes  anio
# 0           1            1         1    1  2025
# 1           1            1        11    1  2025
# 2           1            1        21    1  2025
# 3           1            1        31    1  2025
# 4           1            1        41    1  2025

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas
# Out:
#       id_cliente  id_producto  id_fecha  cantidad  total
# 0              1            1         1         3  18000
# 1              1            1        11         3  18000
# 2              1            1        21         3  18000
# 3              1            1        31         3  18000
# 4              1            1        41         3  18000
# ...          ...          ...       ...       ...    ...
# 4045          90           90        10        10   2000
# 4046          90           90        20        10   2000
# 4047          90           90        30        10   2000
# 4048          90           90        40        10   2000
# 4049          90           90        50        10   2000
#
# [4050 rows x 5 columns]

# %%
fact_ventas.to_sql(
    "fact_ventas",
    engine,
    if_exists="append",
    index=False
)
# Out:
# 50

# %%
productos_db.head()
# Out:
#    id_producto   producto    categoria
# 0            1    Celular  Electronica
# 1            2     Laptop  Electronica
# 2            3     Tablet  Electronica
# 3            4  Impresora      Oficina
# 4            5    Monitor  Electronica

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()
# Out:
#        fecha  nombre   ciudad producto    categoria  cantidad  total  \
# 0 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 1 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 2 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 3 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
# 4 2025-01-12  Carlos  Orizaba  Celular  Electronica         3  18000
#
#    id_cliente  id_producto  id_fecha  mes  anio
# 0           1            1         1    1  2025
# 1           1            1        11    1  2025
# 2           1            1        21    1  2025
# 3           1            1        31    1  2025
# 4           1            1        41    1  2025

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas
# Out:
#       id_cliente  id_producto  id_fecha  cantidad  total
# 0              1            1         1         3  18000
# 1              1            1        11         3  18000
# 2              1            1        21         3  18000
# 3              1            1        31         3  18000
# 4              1            1        41         3  18000
# ...          ...          ...       ...       ...    ...
# 4045          90           90        10        10   2000
# 4046          90           90        20        10   2000
# 4047          90           90        30        10   2000
# 4048          90           90        40        10   2000
# 4049          90           90        50        10   2000
#
# [4050 rows x 5 columns]

# %%
pd.read_sql(
    "SELECT * FROM fact_ventas",
    engine
)
# Out:
#       id_venta  id_cliente  id_producto  id_fecha  cantidad    total
# 0            1           1            1         1         3  18000.0
# 1            2           2            2         2         2  24000.0
# 2            3           3            3         3         4  12000.0
# 3            4           4            4         4         2   5000.0
# 4            5           5            5         5         3   9000.0
# ...        ...         ...          ...       ...       ...      ...
# 6945      6946          90           90        10        10   2000.0
# 6946      6947          90           90        20        10   2000.0
# 6947      6948          90           90        30        10   2000.0
# 6948      6949          90           90        40        10   2000.0
# 6949      6950          90           90        50        10   2000.0
#
# [6950 rows x 6 columns]

# %%
consulta = """
SELECT
    p.producto,
    SUM(f.total) AS ventas_totales
FROM fact_ventas f
JOIN dim_producto p
    ON f.id_producto = p.id_producto
GROUP BY p.producto
ORDER BY ventas_totales DESC
"""

resultado = pd.read_sql(consulta, engine)

resultado
# Out:
#       producto  ventas_totales
# 0       Laptop      16680000.0
# 1      Celular      12510000.0
# 2       Tablet       8340000.0
# 3      Monitor       6255000.0
# 4   Disco Duro       5212500.0
# 5    Impresora       3475000.0
# 6      Teclado       2502000.0
# 7        Mouse       1668000.0
# 8  Memoria USB       1390000.0
# 9       Webcam       1251000.0

# %%
import matplotlib.pyplot as plt

resultado.plot(
    x="producto",
    y="ventas_totales",
    kind="bar"
)

plt.title("Ventas Totales por Producto")
plt.ylabel("Ventas")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.pie(
    resultado["ventas_totales"],
    labels=resultado["producto"],
    autopct="%1.1f%%"
)

plt.title("Porcentaje de Ventas por Producto")

plt.show()
