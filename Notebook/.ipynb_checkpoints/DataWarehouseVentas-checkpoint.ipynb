# %%
import pandas as pd
from sqlalchemy import create_engine
import matplotlib.pyplot as plt

# %%
from sqlalchemy import create_engine

engine = create_engine(
    'postgresql://postgres:edu123@localhost/dw_ventas'
)

print("Conexión exitosa")
# Out:
# Conexión exitosa

# %%
import pandas as pd

df = pd.read_csv("../Data/ventas.csv")

df.head()
# Out:
#         fecha    nombre    ciudad   producto    categoria  cantidad  total
# 0  2025-01-12    Carlos   Orizaba    Celular  Electronica         3  18000
# 1  2025-02-08   Daniela   Cordoba     Laptop  Electronica         2  24000
# 2  2025-03-15  Fernando    Xalapa     Tablet  Electronica         4  12000
# 3  2025-04-10  Gabriela  Veracruz  Impresora      Oficina         2   5000
# 4  2025-05-18    Hector    Puebla    Monitor  Electronica         3   9000

# %%
dim_cliente = df[['nombre','ciudad']].drop_duplicates()

dim_cliente

# %%
dim_producto = df[['producto','categoria']].drop_duplicates()

dim_producto

# %%
dim_fecha = df[['fecha']].drop_duplicates()

dim_fecha['fecha'] = pd.to_datetime(dim_fecha['fecha'])

dim_fecha['mes'] = dim_fecha['fecha'].dt.month
dim_fecha['anio'] = dim_fecha['fecha'].dt.year

dim_fecha

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)

dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)

dim_fecha.to_sql(
    'dim_fecha',
    engine,
    if_exists='append',
    index=False
)

# %%
dim_cliente.to_sql(
    'dim_cliente',
    engine,
    if_exists='append',
    index=False
)

# %%
dim_producto.to_sql(
    'dim_producto',
    engine,
    if_exists='append',
    index=False
)

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

productos_db

# %%
tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

tiempo_db

# %%
clientes_db = pd.read_sql(
    "SELECT * FROM dim_cliente",
    engine
)

clientes_db

# %%
productos_db = pd.read_sql(
    "SELECT * FROM dim_producto",
    engine
)

tiempo_db = pd.read_sql(
    "SELECT * FROM dim_fecha",
    engine
)

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas

# %%
fact_ventas.to_sql(
    "fact_ventas",
    engine,
    if_exists="append",
    index=False
)

# %%
productos_db.head()

# %%
fact = df.merge(
    clientes_db,
    on=["nombre", "ciudad"]
)

# %%
fact = fact.merge(
    productos_db,
    on=["producto", "categoria"]
)

# %%
fact["fecha"] = pd.to_datetime(fact["fecha"])
tiempo_db["fecha"] = pd.to_datetime(tiempo_db["fecha"])

fact = fact.merge(
    tiempo_db,
    on="fecha"
)

# %%
fact.head()

# %%
fact_ventas = fact[
    [
        "id_cliente",
        "id_producto",
        "id_fecha",
        "cantidad",
        "total"
    ]
]

fact_ventas

# %%
pd.read_sql(
    "SELECT * FROM fact_ventas",
    engine
)

# %%
consulta = """
SELECT
    p.producto,
    SUM(f.total) AS ventas_totales
FROM fact_ventas f
JOIN dim_producto p
    ON f.id_producto = p.id_producto
GROUP BY p.producto
ORDER BY ventas_totales DESC
"""

resultado = pd.read_sql(consulta, engine)

resultado

# %%
import matplotlib.pyplot as plt

resultado.plot(
    x="producto",
    y="ventas_totales",
    kind="bar"
)

plt.title("Ventas Totales por Producto")
plt.ylabel("Ventas")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.pie(
    resultado["ventas_totales"],
    labels=resultado["producto"],
    autopct="%1.1f%%"
)

plt.title("Porcentaje de Ventas por Producto")

plt.show()

# %%
import os

print("Carpeta actual:")
print(os.getcwd())
# Out:
# Carpeta actual:
# C:\Users\eduar\Documents\GitHub\Extracci-n-del-Conocimiento-\Notebook

# %%
import os

print(os.path.exists("../Data/ventas.csv"))
# Out:
# True

# %%
import os

print(os.listdir("../Data"))
# Out:
# ['dataset_sucio_practica.csv', 'instagram_dataset.csv']
